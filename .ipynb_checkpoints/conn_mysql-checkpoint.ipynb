# %%
#importando bibliotecas
import os
import pymysql
import pandas as pd

#abrindo conexao com mysql
conn = pymysql.connect(
    host='127.0.0.1',
    port=int(3306),
    user='root',
    passwd='emporium',
    db='emporium',
    charset='utf8mb4')

# %%
df = pd.read_sql_query(
"select * from sale limit 1000",conn)
df.tail(10)
# Out:
#      store_key  pos_number  ticket_number          start_time  voided  \
# 990          1          16         593137 2017-09-02 18:15:08       0
# 991          1          16         593140 2017-09-02 18:16:31       0
# 992          1          16         593143 2017-09-02 18:17:28       0
# 993          1          16         593144 2017-09-02 18:19:18       0
# 994          1          16         593147 2017-09-02 18:22:04       0
# 995          1          16         593150 2017-09-02 18:25:31       0
# 996          1          16         593151 2017-09-02 18:26:51       0
# 997          1          16         593152 2017-09-02 18:29:19       0
# 998          1          16         593155 2017-09-02 18:30:42       0
# 999          1          16         593158 2017-09-02 18:31:43       0
#
#      post_sale_void  sale_type  customer_key  amount_due  change_amount  \
# 990               0          0             0       12.69           0.00
# ...
